# %% [markdown]
# <a href="https://colab.research.google.com/github/abstrusoo/Fonte_dados/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Análise de dados sorvete

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sakshisatre/ice-cream-sales-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/sakshisatre/ice-cream-sales-dataset/versions/1

# %%
import pandas as pd
import os
file_path = os.path.join(path, 'Ice Cream.csv')
df = pd.read_csv(file_path)
display(df.head())
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Temperature', y='Revenue', data=df)
plt.title('Venda vs Temperatura')
plt.xlabel('Temperatura')
plt.ylabel('Vendas')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Temperature', y='Revenue', data=df, label='Dados')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Linha de Regressão')
plt.title('Venda vs Temperatura - Regressão')
plt.xlabel('Temperatura')
plt.ylabel('Venda')
plt.legend()
plt.grid(True)
plt.show()
